# %%
import os
import math 
import pandas as pd

main_directory = "/home/student/Desktop/Dataset Creation/Statements to Dataset/Financial_Statements"

folders = [folder for folder in os.listdir(main_directory) if os.path.isdir(os.path.join(main_directory, folder))]

count = 0

def safe_divide(a, b):
    if float(b) == 0:
        return 0  # Return 0 if denominator is zero to avoid division by zero error
    else:
        return float(a) / float(b)


# Loop through each folder
for folder_name in folders:
    print(f"Processing folder: {folder_name}")
    folder_path = os.path.join(main_directory, folder_name)


    bal_sheet = pd.read_csv(os.path.join(folder_path, "Merged_Balance_Sheet.csv"))
    cf_sheet = pd.read_csv(os.path.join(folder_path, "Merged_Cash_Flow.csv"))
    pl_sheet = pd.read_csv(os.path.join(folder_path, "Merged_Profit_Loss.csv"))
    ratio_sheet = pd.read_csv(os.path.join(folder_path, "Merged_Ratio.csv"))



    # BALANCE SHEET VARIABLES
    Equity_Share_Capital = bal_sheet[bal_sheet.iloc[:, 0] == 'Equity_Share_Capital'].iloc[:, 1:-1]
    Total_Share_Capital = bal_sheet[bal_sheet.iloc[:, 0] == 'Total_Share_Capital'].iloc[:, 1:-1]
    Reserves_and_Surplus = bal_sheet[bal_sheet.iloc[:, 0] == 'Reserves_and_Surplus'].iloc[:, 1:-1]
    Total_Reserves_and_Surplus = bal_sheet[bal_sheet.iloc[:, 0] == 'Total_Reserves_and_Surplus'].iloc[:, 1:-1]
    Total_Shareholders_Funds = bal_sheet[bal_sheet.iloc[:, 0] == 'Total_Shareholders_Funds'].iloc[:, 1:-1]
    Minority_Interest = bal_sheet[bal_sheet.iloc[:, 0] == 'Minority_Interest'].iloc[:, 1:-1]
    NON_CURRENT_LIABILITIES = bal_sheet[bal_sheet.iloc[:, 0] == 'NON-CURRENT_LIABILITIES'].iloc[:, 1:-1]
    Long_Term_Borrowings = bal_sheet[bal_sheet.iloc[:, 0] == 'Long_Term_Borrowings'].iloc[:, 1:-1]
    Deferred_Tax_Liabilities_Net = bal_sheet[bal_sheet.iloc[:, 0] == 'Deferred_Tax_Liabilities_[Net]'].iloc[:, 1:-1]
    Other_Long_Term_Liabilities = bal_sheet[bal_sheet.iloc[:, 0] == 'Other_Long_Term_Liabilities'].iloc[:, 1:-1]
    Long_Term_Provisions = bal_sheet[bal_sheet.iloc[:, 0] == 'Long_Term_Provisions'].iloc[:, 1:-1]
    Total_Non_Current_Liabilities = bal_sheet[bal_sheet.iloc[:, 0] == 'Total_Non-Current_Liabilities'].iloc[:, 1:-1]
    CURRENT_LIABILITIES = bal_sheet[bal_sheet.iloc[:, 0] == 'CURRENT_LIABILITIES'].iloc[:, 1:-1]
    Short_Term_Borrowings = bal_sheet[bal_sheet.iloc[:, 0] == 'Short_Term_Borrowings'].iloc[:, 1:-1]
    Trade_Payables = bal_sheet[bal_sheet.iloc[:, 0] == 'Trade_Payables'].iloc[:, 1:-1]
    Other_Current_Liabilities = bal_sheet[bal_sheet.iloc[:, 0] == 'Other_Current_Liabilities'].iloc[:, 1:-1]
    Short_Term_Provisions = bal_sheet[bal_sheet.iloc[:, 0] == 'Short_Term_Provisions'].iloc[:, 1:-1]
    Total_Current_Liabilities = bal_sheet[bal_sheet.iloc[:, 0] == 'Total_Current_Liabilities'].iloc[:, 1:-1]
    Total_Capital_And_Liabilities = bal_sheet[bal_sheet.iloc[:, 0] == 'Total_Capital_And_Liabilities'].iloc[:, 1:-1]
    ASSETS = bal_sheet[bal_sheet.iloc[:, 0] == 'ASSETS'].iloc[:, 1:-1]
    NON_CURRENT_ASSETS = bal_sheet[bal_sheet.iloc[:, 0] == 'NON-CURRENT_ASSETS'].iloc[:, 1:-1]
    Tangible_Assets = bal_sheet[bal_sheet.iloc[:, 0] == 'Tangible_Assets'].iloc[:, 1:-1]
    Intangible_Assets = bal_sheet[bal_sheet.iloc[:, 0] == 'Intangible_Assets'].iloc[:, 1:-1]
    Capital_Work_In_Progress = bal_sheet[bal_sheet.iloc[:, 0] == 'Capital_Work-In-Progress'].iloc[:, 1:-1]
    Fixed_Assets = bal_sheet[bal_sheet.iloc[:, 0] == 'Fixed_Assets'].iloc[:, 1:-1]
    Non_Current_Investments = bal_sheet[bal_sheet.iloc[:, 0] == 'Non-Current_Investments'].iloc[:, 1:-1]
    Deferred_Tax_Assets_Net = bal_sheet[bal_sheet.iloc[:, 0] == 'Deferred_Tax_Assets_[Net]'].iloc[:, 1:-1]
    Long_Term_Loans_And_Advances = bal_sheet[bal_sheet.iloc[:, 0] == 'Long_Term_Loans_And_Advances'].iloc[:, 1:-1]
    Other_Non_Current_Assets = bal_sheet[bal_sheet.iloc[:, 0] == 'Other_Non-Current_Assets'].iloc[:, 1:-1]
    Total_Non_Current_Assets = bal_sheet[bal_sheet.iloc[:, 0] == 'Total_Non-Current_Assets'].iloc[:, 1:-1]
    CURRENT_ASSETS = bal_sheet[bal_sheet.iloc[:, 0] == 'CURRENT_ASSETS'].iloc[:, 1:-1]
    Current_Investments = bal_sheet[bal_sheet.iloc[:, 0] == 'Current_Investments'].iloc[:, 1:-1]
    Inventories = bal_sheet[bal_sheet.iloc[:, 0] == 'Inventories'].iloc[:, 1:-1]
    Trade_Receivables = bal_sheet[bal_sheet.iloc[:, 0] == 'Trade_Receivables'].iloc[:, 1:-1]
    Cash_And_Cash_Equivalents = bal_sheet[bal_sheet.iloc[:, 0] == 'Cash_And_Cash_Equivalents'].iloc[:, 1:-1]
    Short_Term_Loans_And_Advances = bal_sheet[bal_sheet.iloc[:, 0] == 'Short_Term_Loans_And_Advances'].iloc[:, 1:-1]
    OtherCurrentAssets = bal_sheet[bal_sheet.iloc[:, 0] == 'OtherCurrentAssets'].iloc[:, 1:-1]
    Total_Current_Assets = bal_sheet[bal_sheet.iloc[:, 0] == 'Total_Current_Assets'].iloc[:, 1:-1]
    Total_Assets = bal_sheet[bal_sheet.iloc[:, 0] == 'Total_Assets'].iloc[:, 1:-1]
    OTHER_ADDITIONAL_INFORMATION = bal_sheet[bal_sheet.iloc[:, 0] == 'OTHER_ADDITIONAL_INFORMATION'].iloc[:, 1:-1]
    CONTINGENT_LIABILITIES_COMMITMENTS = bal_sheet[bal_sheet.iloc[:, 0] == 'CONTINGENT_LIABILITIES,_COMMITMENTS'].iloc[:, 1:-1]
    Contingent_Liabilities = bal_sheet[bal_sheet.iloc[:, 0] == 'Contingent_Liabilities'].iloc[:, 1:-1]
    BONUS_DETAILS = bal_sheet[bal_sheet.iloc[:, 0] == 'BONUS_DETAILS'].iloc[:, 1:-1]
    Bonus_Equity_Share_Capital = bal_sheet[bal_sheet.iloc[:, 0] == 'Bonus_Equity_Share_Capital'].iloc[:, 1:-1]
    NON_CURRENT_INVESTMENTS = bal_sheet[bal_sheet.iloc[:, 0] == 'NON-CURRENT_INVESTMENTS'].iloc[:, 1:-1]
    Non_Current_Investments_Quoted_Market_Value = bal_sheet[bal_sheet.iloc[:, 0] == 'Non-Current_Investments_Quoted_Market_Value'].iloc[:, 1:-1]
    Current_Investments_Unquoted_Book_Value = bal_sheet[bal_sheet.iloc[:, 0] == 'Current_Investments_Unquoted_Book_Value'].iloc[:, 1:-1]
    # CASH FLOW VARIABLES
    Net_Profit_Loss_Before_Extraordinary_Items_And_Tax = cf_sheet[cf_sheet.iloc[:, 0] == 'Net_Profit/Loss_Before_Extraordinary_Items_And_Tax'].iloc[:, 1:-1]
    Net_CashFlow_From_Operating_Activities = cf_sheet[cf_sheet.iloc[:, 0] == 'Net_CashFlow_From_Operating_Activities'].iloc[:, 1:-1]
    Net_Cash_Used_In_Investing_Activities = cf_sheet[cf_sheet.iloc[:, 0] == 'Net_Cash_Used_In_Investing_Activities'].iloc[:, 1:-1]
    Net_Cash_Used_From_Financing_Activities = cf_sheet[cf_sheet.iloc[:, 0] == 'Net_Cash_Used_From_Financing_Activities'].iloc[:, 1:-1]
    Foreign_Exchange_Gains_Losses = cf_sheet[cf_sheet.iloc[:, 0] == 'Foreign_Exchange_Gains_/_Losses'].iloc[:, 1:-1]
    Adjustments_On_Amalgamation_Merger_Demerger_Others = cf_sheet[cf_sheet.iloc[:, 0] == 'Adjustments_On_Amalgamation_Merger_Demerger_Others'].iloc[:, 1:-1]
    Net_Inc_Dec_In_Cash_And_Cash_Equivalents = cf_sheet[cf_sheet.iloc[:, 0] == 'Net_Inc/Dec_In_Cash_And_Cash_Equivalents'].iloc[:, 1:-1]
    Cash_And_Cash_Equivalents_Begin_of_Year = cf_sheet[cf_sheet.iloc[:, 0] == 'Cash_And_Cash_Equivalents_Begin_of_Year'].iloc[:, 1:-1]
    Cash_And_Cash_Equivalents_End_Of_Year = cf_sheet[cf_sheet.iloc[:, 0] == 'Cash_And_Cash_Equivalents_End_Of_Year'].iloc[:, 1:-1]
    # PROFIT LOSS VARIABLES
    Revenue_From_Operations_Gross = pl_sheet[pl_sheet.iloc[:, 0] == 'Revenue_From_Operations_[Gross]'].iloc[:, 1:-1]
    # print(Revenue_From_Operations_Gross)
    Less_Excise_Service_Tax_Other_Levies = pl_sheet[pl_sheet.iloc[:, 0] == 'Less:_Excise/Sevice_Tax/Other_Levies'].iloc[:, 1:-1]
    Revenue_From_Operations_Net = pl_sheet[pl_sheet.iloc[:, 0] == 'Revenue_From_Operations_[Net]'].iloc[:, 1:-1]
    Total_Operating_Revenues = pl_sheet[pl_sheet.iloc[:, 0] == 'Total_Operating_Revenues'].iloc[:, 1:-1]
    Other_Income = pl_sheet[pl_sheet.iloc[:, 0] == 'Other_Income'].iloc[:, 1:-1]
    Total_Revenue = pl_sheet[pl_sheet.iloc[:, 0] == 'Total_Revenue'].iloc[:, 1:-1]
    EXPENSES = pl_sheet[pl_sheet.iloc[:, 0] == 'EXPENSES'].iloc[:, 1:-1]
    Cost_Of_Materials_Consumed = pl_sheet[pl_sheet.iloc[:, 0] == 'Cost_Of_Materials_Consumed'].iloc[:, 1:-1]
    Purchase_Of_Stock_In_Trade = pl_sheet[pl_sheet.iloc[:, 0] == 'Purchase_Of_Stock-In_Trade'].iloc[:, 1:-1]
    Operating_And_Direct_Expenses = pl_sheet[pl_sheet.iloc[:, 0] == 'Operating_And_Direct_Expenses'].iloc[:, 1:-1]
    Changes_In_Inventories_Of_FGWIP_And_Stock_In_Trade = pl_sheet[pl_sheet.iloc[:, 0] == 'Changes_In_Inventories_Of_FGWIP_And_Stock_In_Trade'].iloc[:, 1:-1]
    Employee_Benefit_Expenses = pl_sheet[pl_sheet.iloc[:, 0] == 'Employee_Benefit_Expenses'].iloc[:, 1:-1]
    Finance_Costs = pl_sheet[pl_sheet.iloc[:, 0] == 'Finance_Costs'].iloc[:, 1:-1]
    Depreciation_And_Amortisation_Expenses = pl_sheet[pl_sheet.iloc[:, 0] == 'Depreciation_And_Amortisation_Expenses'].iloc[:, 1:-1]
    Other_Expenses = pl_sheet[pl_sheet.iloc[:, 0] == 'Other_Expenses'].iloc[:, 1:-1]
    Total_Expenses = pl_sheet[pl_sheet.iloc[:, 0] == 'Total_Expenses'].iloc[:, 1:-1]
    Profit_Loss_Before_Exceptional_ExtraOrdinary_Items_And_Tax = pl_sheet[pl_sheet.iloc[:, 0] == 'Profit/Loss_Before_Exceptional,_ExtraOrdinary_Items_And_Tax'].iloc[:, 1:-1]
    Exceptional_Items = pl_sheet[pl_sheet.iloc[:, 0] == 'Exceptional_Items'].iloc[:, 1:-1]
    Profit_Loss_Before_Tax = pl_sheet[pl_sheet.iloc[:, 0] == 'Profit/Loss_Before_Tax'].iloc[:, 1:-1]
    Tax_Expenses_Continued_Operations = pl_sheet[pl_sheet.iloc[:, 0] == 'Tax_Expenses-Continued_Operations'].iloc[:, 1:-1]
    Current_Tax = pl_sheet[pl_sheet.iloc[:, 0] == 'Current_Tax'].iloc[:, 1:-1]
    Less_MAT_Credit_Entitlement = pl_sheet[pl_sheet.iloc[:, 0] == 'Less:_MAT_Credit_Entitlement'].iloc[:, 1:-1]
    Deferred_Tax = pl_sheet[pl_sheet.iloc[:, 0] == 'Deferred_Tax'].iloc[:, 1:-1]
    Other_Direct_Taxes = pl_sheet[pl_sheet.iloc[:, 0] == 'Other_Direct_Taxes'].iloc[:, 1:-1]
    Total_Tax_Expenses = pl_sheet[pl_sheet.iloc[:, 0] == 'Total_Tax_Expenses'].iloc[:, 1:-1]
    Profit_Loss_After_Tax_And_Before_ExtraOrdinary_Items = pl_sheet[pl_sheet.iloc[:, 0] == 'Profit/Loss_After_Tax_And_Before_ExtraOrdinary_Items'].iloc[:, 1:-1]
    Profit_Loss_From_Continuing_Operations = pl_sheet[pl_sheet.iloc[:, 0] == 'Profit/Loss_From_Continuing_Operations'].iloc[:, 1:-1]
    Profit_Loss_For_The_Period = pl_sheet[pl_sheet.iloc[:, 0] == 'Profit/Loss_For_The_Period'].iloc[:, 1:-1]
    Minority_Interest = pl_sheet[pl_sheet.iloc[:, 0] == 'Minority_Interest'].iloc[:, 1:-1]
    Consolidated_Profit_Loss_After_MI_And_Associates = pl_sheet[pl_sheet.iloc[:, 0] == 'Consolidated_Profit/Loss_After_MI_And_Associates'].iloc[:, 1:-1]
    OTHER_ADDITIONAL_INFORMATION = pl_sheet[pl_sheet.iloc[:, 0] == 'OTHER_ADDITIONAL_INFORMATION'].iloc[:, 1:-1]
    EARNINGS_PER_SHARE = pl_sheet[pl_sheet.iloc[:, 0] == 'EARNINGS_PER_SHARE'].iloc[:, 1:-1]
    Basic_EPS_Rs = pl_sheet[pl_sheet.iloc[:, 0] == 'Basic_EPS_(Rs.)'].iloc[:, 1:-1]
    Diluted_EPS_Rs = pl_sheet[pl_sheet.iloc[:, 0] == 'Diluted_EPS_(Rs.)'].iloc[:, 1:-1]
    DIVIDEND_AND_DIVIDEND_PERCENTAGE = pl_sheet[pl_sheet.iloc[:, 0] == 'DIVIDEND_AND_DIVIDEND_PERCENTAGE'].iloc[:, 1:-1]
    Equity_Share_Dividend = pl_sheet[pl_sheet.iloc[:, 0] == 'Equity_Share_Dividend'].iloc[:, 1:-1]
    Tax_On_Dividend = pl_sheet[pl_sheet.iloc[:, 0] == 'Tax_On_Dividend'].iloc[:, 1:-1]

    # RATIO VARIABLES
    Basic_EPS_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Basic_EPS_(Rs.)'].iloc[:, 1:-1]
    Diluted_EPS_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Diluted_EPS_(Rs.)'].iloc[:, 1:-1]
    Cash_EPS_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Cash_EPS_(Rs.)'].iloc[:, 1:-1]
    Book_Value_ExclRevalReserve_Share_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Book_Value_[ExclRevalReserve]/Share_(Rs.)'].iloc[:, 1:-1]
    Book_Value_InclRevalReserve_Share_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Book_Value_[InclRevalReserve]/Share_(Rs.)'].iloc[:, 1:-1]
    Revenue_from_Operations_Share_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Revenue_from_Operations/Share_(Rs.)'].iloc[:, 1:-1]
    PBDIT_Share_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'PBDIT/Share_(Rs.)'].iloc[:, 1:-1]
    PBIT_Share_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'PBIT/Share_(Rs.)'].iloc[:, 1:-1]
    PBT_Share_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'PBT/Share_(Rs.)'].iloc[:, 1:-1]
    Net_Profit_Share_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Net_Profit/Share_(Rs.)'].iloc[:, 1:-1]
    NP_After_MI_And_SOA_Share_Rs = ratio_sheet[ratio_sheet.iloc[:, 0] == 'NP_After_MI_And_SOA_/_Share_(Rs.)'].iloc[:, 1:-1]
    Profitability_Ratios = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Profitability_Ratios'].iloc[:, 1:-1]
    PBDIT_Margin = ratio_sheet[ratio_sheet.iloc[:, 0] == 'PBDIT_Margin_(%)'].iloc[:, 1:-1]
    PBIT_Margin = ratio_sheet[ratio_sheet.iloc[:, 0] == 'PBIT_Margin_(%)'].iloc[:, 1:-1]
    PBT_Margin = ratio_sheet[ratio_sheet.iloc[:, 0] == 'PBT_Margin_(%)'].iloc[:, 1:-1]
    Net_Profit_Margin = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Net_Profit_Margin_(%)'].iloc[:, 1:-1]
    NP_After_MI_And_SOA_Margin = ratio_sheet[ratio_sheet.iloc[:, 0] == 'NP_After_MI_And_SOA_Margin_(%)'].iloc[:, 1:-1]
    Return_on_Networth_Equity = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Return_on_Networth/Equity_(%)'].iloc[:, 1:-1]
    Return_on_Capital_Employed = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Return_on_Capital_Employed_(%)'].iloc[:, 1:-1]
    Return_on_Assets = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Return_on_Assets_(%)'].iloc[:, 1:-1]
    Total_Debt_Equity = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Total_Debt/Equity_(X)'].iloc[:, 1:-1]
    Asset_Turnover_Ratio = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Asset_Turnover_Ratio_(%)'].iloc[:, 1:-1]
    Liquidity_Ratios = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Liquidity_Ratios'].iloc[:, 1:-1]
    Current_Ratio = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Current_Ratio_(X)'].iloc[:, 1:-1]
    Quick_Ratio = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Quick_Ratio_(X)'].iloc[:, 1:-1]
    Inventory_Turnover_Ratio = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Inventory_Turnover_Ratio_(X)'].iloc[:, 1:-1]
    Dividend_Payout_Ratio_NP = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Dividend_Payout_Ratio_(NP)_(%)'].iloc[:, 1:-1]
    Dividend_Payout_Ratio_CP = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Dividend_Payout_Ratio_(CP)_(%)'].iloc[:, 1:-1]
    Earnings_Retention_Ratio = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Earnings_Retention_Ratio_(%)'].iloc[:, 1:-1]
    Cash_Earnings_Retention_Ratio = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Cash_Earnings_Retention_Ratio_(%)'].iloc[:, 1:-1]
    Coverage_Ratios = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Coverage_Ratios'].iloc[:, 1:-1]
    Interest_Coverage_Ratios = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Interest_Coverage_Ratios_(%)'].iloc[:, 1:-1]
    Interest_Coverage_Ratios_Post_Tax = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Interest_Coverage_Ratios_(Post_Tax)_(%)'].iloc[:, 1:-1]
    Valuation_Ratios = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Valuation_Ratios'].iloc[:, 1:-1]
    Enterprise_Value = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Enterprise_Value_(Cr.)'].iloc[:, 1:-1]
    EV_Net_Operating_Revenue = ratio_sheet[ratio_sheet.iloc[:, 0] == 'EV/Net_Operating_Revenue_(X)'].iloc[:, 1:-1]
    EV_EBITDA = ratio_sheet[ratio_sheet.iloc[:, 0] == 'EV/EBITDA_(X)'].iloc[:, 1:-1]
    MarketCap_Net_Operating_Revenue = ratio_sheet[ratio_sheet.iloc[:, 0] == 'MarketCap/Net_Operating_Revenue_(X)'].iloc[:, 1:-1]
    Retention_Ratios = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Retention_Ratios_(%)'].iloc[:, 1:-1]
    Price_BV = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Price/BV_(X)'].iloc[:, 1:-1]
    Price_Net_Operating_Revenue = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Price/Net_Operating_Revenue'].iloc[:, 1:-1]
    Earnings_Yield = ratio_sheet[ratio_sheet.iloc[:, 0] == 'Earnings_Yield'].iloc[:, 1:-1]

    # FORMULA FOR CALCULATIONS

    column_names = Equity_Share_Capital.columns.tolist() 
    column_names = ['Feature_name'] + column_names


    all_ratios = pd.DataFrame(columns=column_names)


    temp = Current_Ratio
    temp.insert(0, 'Feature_name', 'x1')
    all_ratios = pd.concat([all_ratios, temp], ignore_index=True)

    temp = Quick_Ratio
    temp.insert(0, 'Feature_name', 'x2')
    all_ratios = pd.concat([all_ratios, temp], ignore_index=True)

    A = Cash_And_Cash_Equivalents.iloc[0].tolist()
    B = Total_Current_Liabilities.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x3')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    temp = Total_Debt_Equity
    temp.insert(0, 'Feature_name', 'x4')
    all_ratios = pd.concat([all_ratios, temp], ignore_index=True)

    A = Total_Current_Liabilities.iloc[0].tolist()
    B = Total_Capital_And_Liabilities.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x5')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Equity_Share_Capital.iloc[0].tolist()  
    B = Fixed_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]  
    result.insert(0, 'x6')
    new_row = pd.DataFrame([result], columns = Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)
    
    temp = Asset_Turnover_Ratio
    temp.insert(0, 'Feature_name', 'x7')
    all_ratios = pd.concat([all_ratios, temp], ignore_index=True)

    A = Revenue_From_Operations_Gross.iloc[0].tolist()
    B = Employee_Benefit_Expenses.iloc[0].tolist()
    result = [float(a) - float(b) for a, b in zip(A, B)]
    Net_Sales = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    A = Total_Assets.iloc[0].tolist()
    B = A[1:]
    avg = [safe_divide((float(a) + float(b)), 2) for a, b in zip(A, B)]
    avg.append(math.nan)
    temp = pd.DataFrame([avg], columns = Revenue_From_Operations_Gross.columns)
    A = temp.iloc[0].tolist()  
    B = Net_Sales.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]  
    result.insert(0, 'x8')
    new_row = pd.DataFrame([result], columns = Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)
    

    A = Revenue_From_Operations_Gross.iloc[0].tolist()
    B = Net_Sales.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x9')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Revenue_From_Operations_Gross.iloc[0].tolist()  
    B = Operating_And_Direct_Expenses.iloc[0].tolist()  
    C = Depreciation_And_Amortisation_Expenses.iloc[0].tolist()  
    result = [float(a) - float(b) - float(b) for a, b, c in zip(A, B, C)]  
    Operating_Profit = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)
    print(Operating_Profit)
    A = Operating_Profit.iloc[0].tolist()  
    B = Net_Sales.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)] 
    result.insert(0, 'x10')
    new_row = pd.DataFrame([result], columns = Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    temp = Net_Profit_Margin
    temp.insert(0, 'Feature_name', 'x11')
    all_ratios = pd.concat([all_ratios, temp], ignore_index=True)

    A = Profit_Loss_For_The_Period.iloc[0].tolist()
    B = Net_Sales.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x12')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Current_Liabilities.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x13')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)


    A = Total_Current_Assets.iloc[0].tolist()
    B = Total_Current_Liabilities.iloc[0].tolist()

    result = [float(a) - float(b) for a, b in zip(A, B)]
    Working_Capital = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    A = Working_Capital.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x14')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Revenue.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x15')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Assets.iloc[0].tolist()
    B = A[1:]

    differences = [float(a) - float(b) for a, b in zip(A, B)]
    differences.append(math.nan)

    temp = pd.DataFrame([differences], columns = Revenue_From_Operations_Gross.columns)

    print(temp)
    A = temp.iloc[0].tolist()  
    B = Total_Assets.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]  
    result.insert(0, 'x16')
    new_row = pd.DataFrame([result], columns = Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)
    # print(all_ratios)

    A = Profit_Loss_For_The_Period.iloc[0].tolist()
    B = Net_Sales.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x17')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Cash_And_Cash_Equivalents.iloc[0].tolist()
    B = Current_Investments.iloc[0].tolist()

    result = [float(a) + float(b) for a, b in zip(A, B)]
    Cash_and_Short_term_Investment = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    A = Cash_and_Short_term_Investment.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x18')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Current_Liabilities.iloc[0].tolist()
    B = Total_Non_Current_Liabilities.iloc[0].tolist()

    result = [float(a) + float(b) for a, b in zip(A, B)]
    Total_Liability = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    A = Total_Assets.iloc[0].tolist()
    B = Total_Liability.iloc[0].tolist()

    result = [float(a) - float(b) for a, b in zip(A, B)]
    Market_Equity = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    A = Cash_and_Short_term_Investment.iloc[0].tolist()
    B = Market_Equity.iloc[0].tolist()
    C = Total_Liability.iloc[0].tolist()

    result = [safe_divide(a, (b + c)) for a, b, c in zip(A, B, C)]
    result.insert(0, 'x19')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Cash_And_Cash_Equivalents.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x20')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Cash_And_Cash_Equivalents.iloc[0].tolist()
    B = Total_Current_Liabilities.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x21')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Inventories.iloc[0].tolist()
    B = A[1:]

    differences = [float(a) - float(b) for a, b in zip(A, B)]
    differences.append(math.nan)

    temp = pd.DataFrame([differences], columns = Revenue_From_Operations_Gross.columns)

    print(temp)
    A = temp.iloc[0].tolist() 
    B = Inventories.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]  
    result.insert(0, 'x22')
    new_row = pd.DataFrame([result], columns = Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)
    # print(all_ratios)

    A = Inventories.iloc[0].tolist()
    B = Net_Sales.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x23')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Current_Liabilities.iloc[0].tolist()
    B = Cash_And_Cash_Equivalents.iloc[0].tolist()

    result = [float(a) - float(b) for a, b in zip(A, B)]
    temp = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    A = temp.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x24')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)



    A = Total_Current_Liabilities.iloc[0].tolist()
    B = Net_Sales.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x25')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Liability.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x26')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Market_Equity.iloc[0].tolist()
    B = Total_Liability.iloc[0].tolist()

    result = [float(a) + float(b) for a, b in zip(A, B)]
    temp = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    A = Total_Liability.iloc[0].tolist()
    B = temp.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x27')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)



    A = Total_Revenue.iloc[0].tolist()
    B = Total_Expenses.iloc[0].tolist()

    result = [float(a) - float(b) for a, b in zip(A, B)]
    Net_Income = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    A = Net_Income.iloc[0].tolist()
    B = temp.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x28')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Operating_Revenues.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x29')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Operating_Revenues.iloc[0].tolist()
    B = Net_Sales.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x30')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Assets.iloc[0].tolist()
    B = Inventories.iloc[0].tolist()

    result = [float(a) - float(b) for a, b in zip(A, B)]
    Quick_Assets = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    A = Quick_Assets.iloc[0].tolist()
    B = Total_Current_Liabilities.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x31')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    temp = Dividend_Payout_Ratio_NP
    temp.insert(0, 'Feature_name', 'x32')

    all_ratios = pd.concat([all_ratios, temp], ignore_index=True)

    temp = Return_on_Capital_Employed
    temp.insert(0, 'Feature_name', 'x33')

    all_ratios = pd.concat([all_ratios, temp], ignore_index=True)

    A = Net_Inc_Dec_In_Cash_And_Cash_Equivalents.iloc[0].tolist()
    B = Revenue_From_Operations_Gross.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x34')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Net_CashFlow_From_Operating_Activities.iloc[0].tolist()
    B = Total_Liability.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x35')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Net_Income.iloc[0].tolist()
    B = Total_Tax_Expenses.iloc[0].tolist()

    result = [float(a) + float(b) for a, b in zip(A, B)]
    EBT = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    A = EBT.iloc[0].tolist()
    B = Total_Current_Liabilities.iloc[0].tolist()

    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x36')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)



    A = EBT.iloc[0].tolist()
    B = Market_Equity.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x37')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Market_Equity.iloc[0].tolist()
    B = Total_Liability.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x38')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Revenue_From_Operations_Gross.iloc[0].tolist()
    B = Cost_Of_Materials_Consumed.iloc[0].tolist()
    result = [float(a) - float(b) for a, b in zip(A, B)]
    Gross_Profit = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    print(Gross_Profit)
    A = Gross_Profit.iloc[0].tolist()
    B = Depreciation_And_Amortisation_Expenses.iloc[0].tolist()
    result = [float(a) + float(b) for a, b in zip(A, B)]
    temp = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)

    print(temp)
    A = temp.iloc[0].tolist()
    B = Net_Sales.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x39')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)


    A = Quick_Assets.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x40')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Gross_Profit.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x41')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Operating_And_Direct_Expenses.iloc[0].tolist()
    B = Total_Liability.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x42')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    
    A = Total_Current_Assets.iloc[0].tolist()
    B = Inventories.iloc[0].tolist()
    result = [float(a) - float(b) for a, b in zip(A, B)]
    temp = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)
    print(temp)

    A = temp.iloc[0].tolist()
    B = Total_Current_Liabilities.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x43')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Current_Assets.iloc[0].tolist()
    B = Total_Liability.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x44')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    # A = Total_Current_Liabilities.iloc[0].tolist()
    # B = Total_Assets.iloc[0].tolist()
    # result = [safe_divide(a, b) for a, b in zip(A, B)]
    # result.insert(0, 'x66')
    # new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    # all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    # A = Working_Capital.iloc[0].tolist()
    # B = Fixed_Assets.iloc[0].tolist()
    # result = [safe_divide(a, b) for a, b in zip(A, B)]
    # result.insert(0, 'x48')
    # new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    # all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Current_Assets.iloc[0].tolist()
    B = Inventories.iloc[0].tolist()
    C = Total_Current_Liabilities.iloc[0].tolist()
    result = [float(a) - float(b) - float(c) for a, b, c in zip(A, B, C)]
    temp1 = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)
    print(temp1)

    A = Net_Sales.iloc[0].tolist()
    B = Gross_Profit.iloc[0].tolist()
    C = Depreciation_And_Amortisation_Expenses.iloc[0].tolist()
    result = [float(a) - float(b) - float(c) for a, b, c in zip(A, B, C)]
    temp2 = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)
    print(temp2)

    A = temp1.iloc[0].tolist()
    B = temp2.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x46')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)



    A = Revenue_From_Operations_Gross.iloc[0].tolist()
    B = Operating_And_Direct_Expenses.iloc[0].tolist()
    C = Total_Tax_Expenses.iloc[0].tolist()
    D = Depreciation_And_Amortisation_Expenses.iloc[0].tolist()

    result = [float(a) - float(b) - float(c) - float(d) for a, b, c, d in zip(A, B, C, D)]
    Net_Profit = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)
    print(Net_Profit)

    A = Net_Profit.iloc[0].tolist()
    B = Depreciation_And_Amortisation_Expenses.iloc[0].tolist()
    result = [float(a) + float(b) for a, b in zip(A, B)]
    temp = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)
    print(temp)

    A = temp.iloc[0].tolist()
    B = Total_Liability.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x47')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Working_Capital.iloc[0].tolist()
    B = Fixed_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x48')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Liability.iloc[0].tolist()
    B = Cash_And_Cash_Equivalents.iloc[0].tolist()
    result = [float(a) - float(b) for a, b in zip(A, B)]
    temp = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)
    print(temp)

    A = temp.iloc[0].tolist()
    B = Net_Sales.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x49')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)


    A = Total_Non_Current_Liabilities.iloc[0].tolist()
    B = Market_Equity.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x50')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Current_Assets.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x51')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Current_Liabilities.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x52')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Inventories.iloc[0].tolist()
    B = Working_Capital.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x53')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Inventories.iloc[0].tolist()
    B = Total_Current_Liabilities.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x54')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Current_Liabilities.iloc[0].tolist()
    B = Total_Liability.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x55')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)


    A = Working_Capital.iloc[0].tolist()
    B = Market_Equity.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x56')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Current_Liabilities.iloc[0].tolist()
    B = Market_Equity.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x57')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Non_Current_Liabilities.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x58')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Revenue_From_Operations_Net.iloc[0].tolist()
    B = Total_Expenses.iloc[0].tolist()
    result = [float(a) - float(b) for a, b in zip(A, B)]
    Total_Income = pd.DataFrame([result], columns=Revenue_From_Operations_Gross.columns)
    print(Total_Income)

    A = Total_Income.iloc[0].tolist()
    B = Total_Expenses.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x59')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Total_Expenses.iloc[0].tolist()
    B = Total_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x60')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Net_Sales.iloc[0].tolist()
    B = Quick_Assets.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x61')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)
    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)

    A = Net_Sales.iloc[0].tolist()
    B = Working_Capital.iloc[0].tolist()
    result = [safe_divide(a, b) for a, b in zip(A, B)]
    result.insert(0, 'x62')
    new_row = pd.DataFrame([result], columns=Current_Ratio.columns)

    all_ratios = pd.concat([all_ratios, new_row], ignore_index=True)
    # print(all_ratios)

    # all_ratios = all_ratios.drop(all_ratios.index)

    final_csv_name = "final_" + folder_name + ".csv"
    # all_ratios.to_csv(os.path.join(folder_path, final_csv_name), index=False)
    all_ratios.to_csv(os.path.join(folder_path, "New_Final_Data.csv"), index=False)  
    
    count = count+1
    print(count, end = " ")
# Out:
# Processing folder: Lanco Infratech Limited
#     Mar 17   Mar 16  Mar 15   Mar 14   Mar 13   Mar 12   Mar 11  Mar 10  \
# 0  5502.37  6200.62  6781.6  7955.76  9965.84  7047.86  5540.06  931.15
#
#    Mar 09
# 0  795.56
#     Mar 17   Mar 16   Mar 15  Mar 14   Mar 13    Mar 12    Mar 11  Mar 10  \
# 0  2364.23  1218.66  1828.85   22.91  2407.56  19216.96  13168.45  4479.8
#
#    Mar 09
# 0     NaN
#    Mar 17  Mar 16  Mar 15  Mar 14  Mar 13  Mar 12  Mar 11  Mar 10  Mar 09
# 0  -15.71  -998.4  198.98   23.76   308.7  645.92  516.25  498.17     NaN
#     Mar 17   Mar 16  Mar 15   Mar 14   Mar 13   Mar 12  Mar 11   Mar 10  \
# 0  3243.13  3979.46  4304.4  4081.12  7255.64  5142.94  4680.1  5433.09
#
#     Mar 09
# 0  3856.79
#     Mar 17  Mar 16   Mar 15   Mar 14   Mar 13   Mar 12   Mar 11   Mar 10  \
# 0  4147.01  4797.0  5418.15  5253.03  8381.45  5705.74  5033.83  5780.97
#
#     Mar 09
# 0  3964.13
#     Mar 17   Mar 16   Mar 15  Mar 14   Mar 13   Mar 12  Mar 11   Mar 10  \
# ...
